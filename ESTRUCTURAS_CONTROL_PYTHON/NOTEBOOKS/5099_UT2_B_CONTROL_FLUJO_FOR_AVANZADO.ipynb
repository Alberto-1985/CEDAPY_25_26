# %% [markdown]
# # Módulo 5099: Estructuras de Control en Python
# ## UT3: Aplicaciones Avanzadas del Bucle `for`
#
# En la unidad anterior analizamos los bucles `for` y `while` en sus formas básicas. Ahora, vamos a profundizar en el bucle `for` para resolver problemas más complejos y elegantes.
#
# **Objetivos de esta unidad:**
# * Entender y utilizar la función `enumerate()` para obtener el índice y el valor en un bucle.
# * Dominar el concepto de **bucles anidados** (un bucle dentro de otro).
# * Aplicar bucles anidados para procesar estructuras de datos complejas, como matrices (listas de listas).
# * Utilizar bucles anidados para crear patrones gráficos en la consola.

# %% [markdown]
# ### 1. `enumerate()`: Obteniendo el Índice y el Valor
#
# A menudo, cuando recorremos una lista, no solo queremos saber el *elemento*, sino también su *posición* (índice).
#
# La forma "tradicional" de hacer esto podría ser:
# ```python
# mi_lista = ['a', 'b', 'c']
# for i in range(len(mi_lista)):
#     print(i, mi_lista[i])
# ```
# Esto funciona, pero no es muy "Pythónico" (elegante o simple).
#
# La función `enumerate()` nos simplifica esto enormemente. Envuelve un iterable (como una lista) y, en cada iteración, nos devuelve una tupla con dos valores: `(índice, valor)`.

# %%
alumnos = ['Ana', 'Luis', 'Marta', 'David']

print("--- Ejemplo con enumerate() ---")
# Podemos desempaquetar la tupla directamente en dos variables: 'indice' y 'alumno'
for indice, alumno in enumerate(alumnos):
    print(f"El alumno en la posición {indice} es {alumno}")

print("\n--- Usando 'start' para que el índice empiece en 1 ---")
# Por defecto, el índice empieza en 0. Podemos cambiarlo con el argumento 'start'.
for indice_humano, alumno in enumerate(alumnos, start=1):
    print(f"El alumno nº {indice_humano} es {alumno}")
# Out:
# --- Ejemplo con enumerate() ---
# El alumno en la posición 0 es Ana
# El alumno en la posición 1 es Luis
# El alumno en la posición 2 es Marta
# El alumno en la posición 3 es David
#
# --- Usando 'start' para que el índice empiece en 1 ---
# El alumno nº 1 es Ana
# El alumno nº 2 es Luis
# El alumno nº 3 es Marta
# El alumno nº 4 es David

# %% [markdown]
# ### 2. Bucles `for` Anidados
#
# Un bucle anidado es simplemente **un bucle dentro de otro bucle**.
#
# Es una de las herramientas más potentes que tenemos para trabajar con datos estructurados. La regla fundamental es:
#
# > **Por cada iteración del bucle EXTERNO, el bucle INTERNO se ejecutará por completo.**
#
# Piénsalo como un **reloj**:
# * El **bucle externo** es el *minutero*.
# * El **bucle interno** es el *segundero*.
#
# El minutero (externo) avanza 1 posición. Luego, el segundero (interno) debe dar una vuelta *completa* (60 iteraciones) antes de que el minutero vuelva a avanzar.

# %%
# Bucle externo
for i in range(3):  # Se ejecutará 3 veces (para i=0, i=1, i=2)
    print(f"--- Iteración EXTERNA {i} ---")
    
    # Bucle interno
    for j in range(2): # Se ejecutará 2 veces (para j=0, j=1) POR CADA iteración externa
        print(f"  Iteración interna {j}")
        
    print("--- Fin del bucle interno para i={i} ---\n")
# Out:
# --- Iteración EXTERNA 0 ---
#   Iteración interna 0
#   Iteración interna 1
# --- Fin del bucle interno para i={i} ---
#
# --- Iteración EXTERNA 1 ---
#   Iteración interna 0
#   Iteración interna 1
# --- Fin del bucle interno para i={i} ---
#
# --- Iteración EXTERNA 2 ---
#   Iteración interna 0
#   Iteración interna 1
# --- Fin del bucle interno para i={i} ---

# %% [markdown]
# ### 3. Práctica: Trabajando con Matrices (Listas de Listas)
#
# La aplicación más común de los bucles anidados es recorrer estructuras de datos bidimensionales, como las matrices (que en Python representamos como *listas de listas*).
#
# Imagina una hoja de cálculo o un tablero de ajedrez. Tiene filas y columnas. Para recorrerlo, necesitamos:
# 1.  Un bucle externo para recorrer las **filas**.
# 2.  Un bucle interno para recorrer las **columnas (elementos) de cada fila**.

# %%
# Una matriz de 3x3 representada como una lista de listas
matriz = [
    [1, 2, 3],  # Fila 0
    [4, 5, 6],  # Fila 1
    [7, 8, 9]   # Fila 2
]

print("Elemento en la fila 1, columna 2:", matriz[1][2]) # Imprime el 6

print("\n--- Recorriendo la matriz completa ---")

# El bucle externo recorre la lista "principal". 'fila' será [1, 2, 3], luego [4, 5, 6], etc.
for fila in matriz:
    print(f"Procesando fila: {fila}")
    # El bucle interno recorre la lista "interna" ('fila')
    for elemento in fila:
        # Hacemos algo con cada elemento individual
        print(f"  Elemento individual: {elemento}")
# Out:
# Elemento en la fila 1, columna 2: 6
#
# --- Recorriendo la matriz completa ---
# Procesando fila: [1, 2, 3]
#   Elemento individual: 1
#   Elemento individual: 2
#   Elemento individual: 3
# Procesando fila: [4, 5, 6]
#   Elemento individual: 4
#   Elemento individual: 5
#   Elemento individual: 6
# Procesando fila: [7, 8, 9]
#   Elemento individual: 7
#   Elemento individual: 8
#   Elemento individual: 9

# %% [markdown]
# #### Ejemplo con `enumerate` y matrices
#
# Podemos combinar `enumerate` y bucles anidados para saber la "coordenada" (fila, columna) de cada elemento.

# %%
matriz = [
    ['A', 'B', 'C'],
    ['D', 'E', 'F'],
    ['G', 'H', 'I']
]

# Usamos enumerate en el bucle externo para obtener el índice de la fila (num_fila)
for num_fila, fila in enumerate(matriz):
    # Usamos enumerate en el bucle interno para obtener el índice de la columna (num_columna)
    for num_columna, elemento in enumerate(fila):
        print(f"El elemento '{elemento}' está en la coordenada ({num_fila}, {num_columna})")
# Out:
# El elemento 'A' está en la coordenada (0, 0)
# El elemento 'B' está en la coordenada (0, 1)
# El elemento 'C' está en la coordenada (0, 2)
# El elemento 'D' está en la coordenada (1, 0)
# El elemento 'E' está en la coordenada (1, 1)
# El elemento 'F' está en la coordenada (1, 2)
# El elemento 'G' está en la coordenada (2, 0)
# El elemento 'H' está en la coordenada (2, 1)
# El elemento 'I' está en la coordenada (2, 2)

# %% [markdown]
# ### 4. Práctica: Creación de Patrones
#
# Un ejercicio clásico para dominar los bucles anidados es "dibujar" patrones en la consola. Usamos el bucle externo para controlar las **filas** (las líneas que imprimimos) y el interno para controlar las **columnas** (qué se imprime en cada línea).
#
# **Nota:** Usamos `print(..., end="")` para evitar que `print` haga un salto de línea cada vez.

# %%
print("--- Dibujando un cuadrado 4x4 ---")
lado = 4

for i in range(lado): # Bucle externo: controla las FILAS
    for j in range(lado): # Bucle interno: controla las COLUMNAS
        print("* ", end="") # Imprime un '*' sin saltar de línea
    
    print() # Salto de línea al final de cada fila
# Out:
# --- Dibujando un cuadrado 4x4 ---
# * * * *
# * * * *
# * * * *
# * * * *

# %%
print("--- Dibujando un triángulo rectángulo 5x5 ---")
altura = 5

for i in range(altura): # Bucle externo: controla las FILAS (0, 1, 2, 3, 4)
    # El truco: el bucle interno depende del índice del bucle externo
    # Fila 0: range(0+1) -> range(1) -> imprime 1 estrella
    # Fila 1: range(1+1) -> range(2) -> imprime 2 estrellas
    # Fila 2: range(2+1) -> range(3) -> imprime 3 estrellas
    ...
    for j in range(i + 1): # Bucle interno: controla las COLUMNAS
        print("* ", end="")
        
    print() # Salto de línea al final de cada fila
# Out:
# --- Dibujando un triángulo rectángulo 5x5 ---
# *
# * *
# * * *
# * * * *
# * * * * *

# %% [markdown]
# ---
# ### 🏋️‍♂️ Ejercicios Propuestos
#
# ¡Es tu turno de practicar! Intenta resolver los siguientes problemas.

# %% [markdown]
# #### Ejercicio 1: Suma de todos los elementos de una matriz
#
# Dada la siguiente matriz, utiliza bucles anidados para calcular la suma de todos sus elementos.

# %%
matriz_numeros = [
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
]

# Tu código aquí
# 1. Inicializa una variable 'suma_total' a 0
# 2. Crea un bucle externo para recorrer las filas
# 3. Crea un bucle interno para recorrer los elementos de cada fila
# 4. En el bucle interno, añade el elemento a 'suma_total'
# 5. Imprime el resultado final (debería ser 450)

# %% [markdown]
# #### Ejercicio 2: Tablas de Multiplicar
#
# Utiliza bucles anidados para imprimir las tablas de multiplicar del 1 al 10.
# La salida debería verse algo así:
# ```
# --- Tabla del 1 ---
# 1 x 1 = 1
# 1 x 2 = 2
# ...
# 1 x 10 = 10
# --- Tabla del 2 ---
# 2 x 1 = 2
# ...
# ```

# %%
# Tu código aquí
# 1. El bucle externo debe ir del 1 al 10 (para la tabla)
# 2. El bucle interno debe ir del 1 al 10 (para el multiplicador)
# 3. Imprime el resultado formateado

# %% [markdown]
# #### Ejercicio 3: Encontrar al "Traidor" (¡Reto!)
#
# Tienes una matriz que representa un mapa del tesoro. El tesoro está marcado con una 'X' y el traidor con una "T". Utiliza bucles anidados y `enumerate` para encontrar las coordenadas (fila, columna) del traidor y del tesoro.
#
# Cuando encuentres al traidor, imprime la ubicación y continúa buscando el tesoro.
# Cuando encuentres el tesoro, imprime la ubicación y **detén la búsqueda** (pista: necesitarás usar `break`).

# %%
mapa = [
    ['O', 'O', 'O', 'O', 'O'],
    ['O', 'O', 'T', 'O', 'O'],
    ['O', 'O', 'O', 'O', 'O'],
    ['O', 'O', 'O', 'O', 'X'], # El tesoro está aquí
    ['O', 'O', 'O', 'O', 'O']
]

# Tu código aquí
# 1. Recorre la matriz con 'enumerate' para obtener 'num_fila' y 'fila'
# 2. Recorre cada 'fila' con 'enumerate' para obtener 'num_columna' y 'celda'
# 3. Comprueba si 'celda' es igual a 'X'
# 4. Si lo es, imprime la 'num_fila' y 'num_columna' y sal del bucle (¡investiga cómo salir de un bucle anidado!)
