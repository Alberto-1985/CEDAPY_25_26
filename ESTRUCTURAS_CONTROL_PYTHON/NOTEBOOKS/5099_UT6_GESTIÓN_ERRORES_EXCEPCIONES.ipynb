# %% [markdown]
# # Módulo 5099: Estructuras de Control en Python
# ## Unidad de Trabajo 6: Gestión de Errores y Excepciones
#
# **Objetivo:**
# Esta unidad cubre el **Resultado de Aprendizaje 5** del módulo (RD 566/2024): *"Escribe y prueba programas para el tratamiento de errores y excepciones, utilizando los bloques y sentencias específicas del lenguaje."*
#
# **Introducción:**
# Hasta ahora, nuestros programas funcionan bien cuando el usuario y las condiciones son perfectas. Pero, ¿qué pasa si un usuario introduce texto donde esperamos un número? ¿O si intentamos dividir por cero? ¿O si el archivo que queremos leer no existe?
#
# En estos casos, nuestro programa "rompe" y muestra un error (un **Traceback**). Esto no es aceptable en una aplicación profesional. La **gestión de excepciones** es el conjunto de técnicas que nos permiten *anticipar*, *capturar* y *manejar* estos errores de ejecución de forma elegante, sin que el programa se detenga.

# %% [markdown]
# ### 1. Los Tres Tipos de Errores
#
# En Python, nos enfrentamos a tres categorías de errores:
#
# 1.  **Errores de Sintaxis (SyntaxError):**
#     Ocurren *antes* de que el programa se ejecute. El intérprete de Python no entiende lo que has escrito. Son fáciles de corregir porque el intérprete nos suele indicar la línea.
#     *Ejemplo: `print("Hola"` (falta un paréntesis).*
#
# 2.  **Errores Lógicos (Bugs):**
#     Son los más difíciles de encontrar. El programa se ejecuta perfectamente, pero el resultado es **incorrecto**. La sintaxis es válida, pero la lógica que hemos implementado no es la que queríamos.
#     *Ejemplo: `calculo_media = (nota1 + nota2) / 3` (cuando debería ser `/ 2`).*
#
# 3.  **Errores de Ejecución (Excepciones):**
#     El programa es sintácticamente correcto y arranca, pero *durante la ejecución* ocurre un evento inesperado que lo detiene.
#     *Ejemplo: `10 / 0` o `int("letra")`.*
#
# **Esta unidad se centra en gestionar el tercer tipo: las Excepciones.**

# %%
# Esto es una EXCEPCIÓN: el programa se rompe durante la ejecución.
# Observa el "Traceback": nos dice el tipo de error (ZeroDivisionError) y dónde ocurrió.
print("Voy a dividir...")
resultado = 10 / 0 
print("He dividido.") # Esta línea nunca se ejecutará
# Out:
# Voy a dividir...
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Esto es una EXCEPCIÓN: el programa se rompe durante la ejecución.
#       2 # Observa el "Traceback": nos dice el tipo de error (ZeroDivisionError) y dónde ocurrió.
#       3 print("Voy a dividir...")
# ----> 4 resultado = 10 / 0
#       5 print("He dividido.") # Esta línea nunca se ejecutará
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### 2. El Bloque `try ... except`
#
# Para gestionar una excepción, usamos el bloque `try...except`. La sintaxis es:
#
# ```python
# try:
#     # Código que PUEDE fallar
#     # (El "camino feliz")
# except:
#     # Código que se ejecuta SI Y SÓLO SI
#     # algo falla en el bloque 'try'
#     # (El "plan B")
# ```
#
# Con esto, **evitamos que el programa se detenga**.

# %%
print("Voy a dividir...")
try:
    resultado = 10 / 0
    print(f"El resultado es {resultado}")
except:
    print("¡Error! No se puede dividir por cero.")

print("He terminado el programa.") # Esta línea AHORA SÍ se ejecuta
# Out:
# Voy a dividir...
# ¡Error! No se puede dividir por cero.
# He terminado el programa.

# %% [markdown]
# ### 3. Capturando Excepciones Específicas
#
# Usar un `except:` vacío (llamado "bare except") es una **mala práctica**. Captura *todos* los errores posibles, incluso un `KeyboardInterrupt` (si el usuario pulsa Ctrl+C), y nos impide saber qué salió mal.
#
# Siempre debemos capturar las excepciones específicas que esperamos.

# %%
def pedir_numero():
    try:
        edad_str = input("Introduce tu edad: ")
        edad_num = int(edad_str)
        print(f"El año que viene tendrás {edad_num + 1} años.")
    except ValueError:
        print("Error: Eso no es un número válido.")
    except ZeroDivisionError: # Podemos añadir tantos 'except' como necesitemos
        print("Error: No intentes dividir por cero.")
        
pedir_numero()
# Out:
# El año que viene tendrás 1 años.

# %% [markdown]
# #### Accediendo al objeto de la excepción
#
# Podemos capturar el objeto de la excepción usando `as` para obtener más detalles sobre el error.

# %%
try:
    numero = int("hola")
except ValueError as e:
    print("Ha ocurrido un error:", e)
    print("Tipo de error:", type(e))
# Out:
# Ha ocurrido un error: invalid literal for int() with base 10: 'hola'
# Tipo de error: <class 'ValueError'>

# %% [markdown]
# ### 4. La Estructura Completa: `else` y `finally`
#
# El bloque `try...except` puede tener dos cláusulas adicionales: `else` y `finally`.
#
# ```python
# try:
#     # Código a intentar
# except ValueError as e:
#     # Se ejecuta si hay un ValueError
# else:
#     # Se ejecuta SÓLO SI el bloque 'try'
#     # ha terminado SIN NINGUNA EXCEPCIÓN.
#     # Es el "código de éxito".
# finally:
#     # Se ejecuta SIEMPRE.
#     # Haya o no haya habido excepción.
#     # Es el "código de limpieza".
# ```
#
# La cláusula `finally` es crucial para tareas de "limpieza" que *deben* ocurrir sin importar qué, como cerrar un archivo o una conexión a una base de datos.

# %%
archivo = None # Inicializamos la variable fuera del 'try'
try:
    # Intenta abrir un archivo que podría no existir
    nombre_archivo = input("Nombre del archivo a abrir (ej: 'poema.txt'): ")
    archivo = open(nombre_archivo, 'r')
    contenido = archivo.read()
except FileNotFoundError:
    print(f"Error: El archivo '{nombre_archivo}' no existe.")
except Exception as e:
    print(f"Ha ocurrido un error inesperado: {e}")
else:
    # Si todo fue bien (el archivo se abrió y leyó), mostramos el contenido
    print("--- Contenido del archivo ---")
    print(contenido)
finally:
    # Haya error o no, si el archivo llegó a abrirse, debemos cerrarlo.
    if archivo:
        print("\nCerrando el archivo...")
        archivo.close()

# %% [markdown]
# ### 5. Lanzando Excepciones Deliberadamente: `raise`
#
# A veces, queremos ser nosotros quienes lancemos un error. Si el usuario nos da un dato que es sintácticamente válido (p.ej. un número) pero que no tiene sentido en la lógica de nuestra aplicación (p.ej. una edad negativa), debemos **lanzar una excepción**.
#
# Esto se hace con la palabra clave `raise`.

# %%
def calcular_raiz_cuadrada(numero):
    if numero < 0:
        # Lanzamos un error porque la lógica de negocio no lo permite
        raise ValueError("No se puede calcular la raíz cuadrada de un número negativo")
    return numero ** 0.5

# Ahora, el código que LLAMA a la función debe gestionar este error
try:
    resultado = calcular_raiz_cuadrada(-10)
    print(resultado)
except ValueError as e:
    print(f"Error de validación: {e}")

# %% [markdown]
# ### 6. Creando Excepciones Personalizadas
#
# Podemos crear nuestros propios tipos de error para que nuestra aplicación sea más semántica y clara. Esto se hace creando una clase que herede de la clase base `Exception`.
#
# Esto nos permite crear una jerarquía de errores propia de nuestra aplicación.

# %%
# 1. Creamos nuestra excepción personalizada
class SaldoInsuficienteError(Exception):
    "Se lanza cuando se intenta retirar más saldo del disponible."
    pass

# 2. Creamos nuestro código de aplicación
class CuentaBancaria:
    def __init__(self, saldo_inicial):
        self.saldo = saldo_inicial
    
    def retirar(self, cantidad):
        if cantidad > self.saldo:
            # 3. Lanzamos nuestra excepción personalizada
            raise SaldoInsuficienteError(f"No puedes retirar {cantidad}€, solo tienes {self.saldo}€")
        self.saldo -= cantidad
        return self.saldo

# 4. Gestionamos nuestra excepción personalizada
mi_cuenta = CuentaBancaria(100)

try:
    print("Retirando 50€...")
    mi_cuenta.retirar(50)
    print(f"Saldo restante: {mi_cuenta.saldo}")
    
    print("\nRetirando 80€...")
    mi_cuenta.retirar(80)
    print(f"Saldo restante: {mi_cuenta.saldo}")
    
except SaldoInsuficienteError as e:
    print(f"\nError en la operación: {e}")
except Exception as e:
    print(f"Error inesperado: {e}")
# Out:
# Retirando 50€...
# Saldo restante: 50
#
# Retirando 80€...
#
# Error en la operación: No puedes retirar 80€, solo tienes 50€

# %% [markdown]
# ---
# ### 🏋️‍♂️ Ejercicios Prácticos
#
# Aplica los conceptos aprendidos para resolver los siguientes problemas.

# %% [markdown]
# #### Ejercicio 1: Calculadora Robusta (Nivel Básico)
#
# Crea un programa que pida al usuario dos números y los divida. El programa debe gestionar los siguientes errores y **no debe detenerse** hasta que el usuario decida salir:
# 1.  Si el usuario introduce algo que no es un número (ej: "hola").
# 2.  Si el usuario introduce un cero como segundo número (divisor).

# %%
# Pista: Usa un bucle 'while True' para que el programa se repita
# y un 'input()' para preguntar al usuario si quiere salir.

# Escribe tu código aquí

# %% [markdown]
# #### Ejercicio 2: Procesamiento de Lista (Nivel Intermedio)
#
# Dada la siguiente lista, escribe un bucle que intente convertir cada elemento a `float` y lo añada a una nueva lista llamada `numeros_validos`. Si un elemento no se puede convertir, debe imprimir un mensaje de advertencia y continuar con el siguiente.
#
# Usa un bloque `try-except` dentro del bucle.

# %%
datos_mixtos = ["10.5", "20", "tres", "-5.2", "4.0", "N/A", "8"]
numeros_validos = []

# Escribe tu código aquí


print(f"Los números válidos son: {numeros_validos}")

# %% [markdown]
# #### Ejercicio 3: Validación de Contraseña (Nivel Avanzado)
#
# Crea una excepción personalizada llamada `ErrorValidacionPassword(Exception)`.
#
# Luego, crea una función `registrar_usuario(password)` que valide una contraseña. Esta función debe **lanzar (`raise`)** tu excepción personalizada si la contraseña tiene **menos de 8 caracteres**.
#
# Finalmente, escribe el código que pida al usuario una contraseña y llame a la función `registrar_usuario` dentro de un bloque `try-except` para capturar tu error personalizado.

# %%
# 1. Crea tu excepción personalizada aquí


# 2. Crea tu función 'registrar_usuario' aquí


# 3. Escribe el código principal para pedir la contraseña y gestionar el error
try:
    # Pide la contraseña al usuario
    # Llama a la función
    print("Contraseña válida. Usuario registrado.")
except: # Sustituye esto por tu excepción personalizada
    print("Error: ...")
