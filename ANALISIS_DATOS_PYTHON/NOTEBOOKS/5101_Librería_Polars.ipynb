# %% [markdown]
# # Introducción a **Polars** ⚡
#
# ## ¿Qué es Polars?
#
# **Polars** es una **biblioteca de Python** increíblemente **rápida** diseñada para trabajar con **DataFrames** (conjuntos de datos tabulares).
# Está escrita en **Rust** 🦀 y utiliza **Apache Arrow** como formato de memoria, lo que le permite procesar grandes volúmenes de datos de forma muy eficiente, a menudo mucho más rápido que Pandas.
#
# Permite **analizar, limpiar, transformar y consultar datos** con una sintaxis expresiva y optimizada para el rendimiento.
#
# Fue creada por **Ritchie Vink** y está ganando popularidad rápidamente en la comunidad de ciencia de datos y *Machine Learning* por su velocidad y eficiencia en el uso de memoria.
#
# ---
#
# ## ¿Por qué usar Polars?
#
# En proyectos de **Inteligencia Artificial** y **Machine Learning**, especialmente con **Big Data**, la velocidad y la gestión eficiente de la memoria son cruciales.
#
# Polars destaca porque:
#
# * **Es rapidísimo**: Aprovecha todos los núcleos de tu CPU para paralelizar operaciones.
# * **Maneja datos grandes**: Puede procesar datasets que no caben completamente en la RAM gracias a su motor *lazy* y optimizaciones.
# * **Tiene una API expresiva**: Permite encadenar operaciones de forma clara y lógica (similar a SQL o dplyr en R).
# * **Integra Apache Arrow**: Facilita la interoperabilidad con otras herramientas del ecosistema de datos.
#
#  Polars te ayuda a realizar las mismas tareas que Pandas (limpiar, explorar, transformar), pero a menudo con un **rendimiento significativamente mayor**.
#
# ---
#
# ## Conexión con la Ciencia de Datos
#
# Polars es una herramienta moderna y potente dentro de la **Ciencia de Datos**.
# Se posiciona como una alternativa (o complemento) a Pandas, especialmente útil cuando el **rendimiento** es un factor crítico o se trabaja con **datasets muy grandes**.
#
# Se integra bien con otras bibliotecas como **NumPy**, **PyArrow**, y herramientas de visualización como **Matplotlib** o **Seaborn** (a menudo convirtiendo los datos a Pandas o NumPy para graficar).
#
# ---
#
# ## ¿Qué puede hacer Polars?
#
# Con Polars puedes:
#
# * Leer y escribir datos desde/hacia múltiples formatos (CSV, Parquet, JSON, bases de datos...).
# * Filtrar, ordenar, agrupar y agregar datos de forma muy eficiente.
# * Unir (`join`) y concatenar (`concat`) diferentes DataFrames.
# * Crear nuevas columnas basadas en expresiones complejas.
# * Manejar valores nulos (`null`).
# * Trabajar con datos de series temporales, cadenas de texto, y más.
#
# Una de sus características clave es su **motor de ejecución *lazy*** (perezoso), que optimiza las consultas antes de ejecutarlas.
#
# ---
#
# ## Dónde encontrar Polars
#
# El código fuente de Polars es **abierto y colaborativo**.
# Puedes encontrarlo, junto con su documentación, en:
#
# 🔗 Repositorio oficial en GitHub: [https://github.com/pola-rs/polars](https://github.com/pola-rs/polars)
# 📘 Documentación oficial: [https://docs.pola.rs/](https://docs.pola.rs/)
#
# ---
#
# ## Resumen
#
# | Concepto             | Descripción                                                               |
# | -------------------- | ------------------------------------------------------------------------- |
# | **Polars** | Librería rápida de DataFrames para Python, escrita en Rust.              |
# | **Ventajas** | Velocidad (multicore), eficiencia de memoria, API expresiva, lazy engine. |
# | **Creador** | Ritchie Vink.                                                             |
# | **Backend** | Rust, Apache Arrow.                                                       |
# | **Usos principales** | Procesamiento de datos grandes, Ciencia de Datos, ML, alternativa a Pandas. |
# | **Documentación** | [docs.pola.rs](https://docs.pola.rs/)                                     |
#
# ---

# %% [markdown]
# # **Primeros pasos con Polars** 🚀
#
# ## Instalación de Polars
#
# Para usar Polars, primero necesitas **instalarlo en tu entorno de Python**.
# Si ya tienes **Python** y **PIP** (el gestor de paquetes) instalados, la instalación es muy sencilla.
#
# Ejecuta en tu terminal el siguiente comando:

# %%
pip install polars

# %% [markdown]
# Esto descargará e instalará Polars.
#
# > **Consejo:** Para aprovechar al máximo las optimizaciones, puedes instalar características opcionales. Por ejemplo, para mejor rendimiento con NumPy o interacción con Pandas:
# > ```bash
# > pip install "polars[numpy,pandas]"
# > ```
# > Consulta la [documentación de instalación](https://docs.pola.rs/user-guide/installation/) para más opciones (como soporte para lectura de Excel, Avro, etc.).
#
# Si usas **Anaconda**, también puedes instalarlo con conda:
# ```bash
# conda install polars
# ```
#
# En entornos como **Google Colab**, Polars suele estar preinstalado o se instala fácilmente con `pip`.
#
# ---
#
# ## Importar Polars
#
# Una vez instalado, debes **importar la librería** en tu script o notebook. La convención es usar el alias `pl`:

# %%
import polars as pl

# %% [markdown]
# A partir de ahora, usaremos `pl` para acceder a las funciones y objetos de Polars.
#
# 📘 **Ejemplo básico: Crear un DataFrame**

# %%
import polars as pl

# Crear datos usando un diccionario de Python
data = {
  'modelo': ["Regresión Lineal", "SVM", "Red Neuronal"],
  'accuracy': [0.82, 0.91, 0.88]
}

# Crear un DataFrame de Polars
df = pl.DataFrame(data)

print(df)

# %% [markdown]
# **Qué ocurre aquí:**
#
# * Creamos un **diccionario** `data` donde las claves son los nombres de las columnas y los valores son listas de datos.
# * Usamos `pl.DataFrame(data)` para convertir el diccionario en un **DataFrame** de Polars, la estructura principal para datos tabulares.
# * Imprimimos el DataFrame.
#
# La salida muestra la tabla, indicando el tipo de dato de cada columna (`str` para texto, `f64` para números decimales de 64 bits):
#
# ```
# shape: (3, 2)
# ┌───────────────────┬──────────┐
# │ modelo            ┆ accuracy │
# │ ---               ┆ ---      │
# │ str               ┆ f64      │
# ╞═══════════════════╪══════════╡
# │ Regresión Lineal  ┆ 0.82     │
# │ SVM               ┆ 0.91     │
# │ Red Neuronal      ┆ 0.88     │
# └───────────────────┴──────────┘
# ```
#
# ---
#
# ## Ver la versión de Polars instalada
#
# Para saber qué versión de Polars estás usando, puedes acceder al atributo `__version__`:

# %%
import polars as pl

print(pl.__version__)

# %% [markdown]
# Esto es útil para asegurar la reproducibilidad de tu código y comprobar si tienes acceso a las últimas funcionalidades.
#
# > 🔍 Conocer la versión es importante, ya que Polars evoluciona rápidamente y algunas funciones pueden cambiar o añadirse entre versiones.
#
# ---
#
# ## Resumen visual
#
# | Concepto                     | Descripción                                         |
# | ---------------------------- | --------------------------------------------------- |
# | **Instalación** | `pip install polars`                                |
# | **Importación con alias** | `import polars as pl`                               |
# | **Estructura principal** | `DataFrame` (`pl.DataFrame`)                      |
# | **Ver versión instalada** | `pl.__version__`                                    |
# | **Entornos recomendados** | Cualquiera con Python (local, Colab, Jupyter, etc.) |
#
# ---

# %% [markdown]
# # **Polars Series** 📊
#
# ## ¿Qué es una *Series* en Polars?
#
# Una **Series** de Polars representa una **única columna de datos** en un DataFrame.
# Es una estructura **unidimensional** optimizada para el rendimiento que contiene datos de un **único tipo** (números, texto, fechas, etc.).
#
# Puedes pensar en ella como una columna de una tabla de base de datos o una lista/array de NumPy con funcionalidades adicionales.
#
# **Diferencia clave con Pandas:** Las Series en Polars **no tienen un índice explícito** como en Pandas. El acceso se basa en la posición o mediante expresiones de filtrado.
#
# ---
#
# ## Crear una *Series*
#
# Puedes crear una Series a partir de diferentes estructuras de datos de Python, como listas o tuplas.
#
# 📘 **Ejemplo 1: Desde una lista**

# %%
import polars as pl

datos_lista = [10, 20, 15, 30, 20]
serie_numeros = pl.Series("valores", datos_lista)

print(serie_numeros)

# %% [markdown]
# **Nota:** Al crear una Series, es obligatorio darle un **nombre** (el primer argumento, "valores" en este caso).
#
# 📘 **Ejemplo 2: Serie de texto**

# %%
datos_texto = ["manzana", "plátano", "manzana", "naranja"]
serie_frutas = pl.Series("frutas", datos_texto)

print(serie_frutas)

# %% [markdown]
# ---
#
# ## Acceder a elementos de una *Series*
#
# Puedes acceder a los elementos por su **posición** (índice basado en 0), similar a las listas de Python.
#
# 📘 **Ejemplo: Acceder al primer y tercer elemento**

# %%
# Acceder al primer elemento (posición 0)
print(f"Primer valor: {serie_numeros[0]}")

# Acceder al tercer elemento (posición 2)
print(f"Tercer valor: {serie_numeros[2]}")

# %% [markdown]
# También puedes usar **slicing** para obtener un subconjunto de la Series:

# %%
# Obtener los elementos desde la posición 1 hasta la 3 (sin incluir la 4)
print("Slice [1:4]:")
print(serie_numeros[1:4])

# %% [markdown]
# ---
#
# ## Operaciones básicas con *Series*
#
# Las Series de Polars permiten realizar operaciones vectorizadas (aplicadas a todos los elementos a la vez), lo cual es muy eficiente.
#
# 📘 **Ejemplo: Operaciones aritméticas y comparaciones**

# %%
# Sumar 5 a cada elemento
print("Serie + 5:")
print(serie_numeros + 5)

# Multiplicar por 2
print("\nSerie * 2:")
print(serie_numeros * 2)

# Comparar si los elementos son mayores que 15
print("\nSerie > 15 (devuelve booleanos):")
print(serie_numeros > 15)

# %% [markdown]
# También puedes aplicar funciones estadísticas básicas:

# %%
print(f"\nSuma total: {serie_numeros.sum()}")
print(f"Valor medio: {serie_numeros.mean()}")
print(f"Valor máximo: {serie_numeros.max()}")
print(f"Número de elementos únicos: {serie_frutas.n_unique()}")
print("Valores únicos y sus cuentas:")
print(serie_frutas.value_counts())

# %% [markdown]
# ---
#
# ## De Series a DataFrame
#
# Un **DataFrame** en Polars es esencialmente una **colección de Series** con el mismo número de filas, donde cada Series representa una columna.
#
# Puedes construir un DataFrame a partir de varias Series:
#
# 📘 **Ejemplo:**

# %%
import polars as pl

serie_calorias = pl.Series("calories", [420, 380, 390])
serie_duracion = pl.Series("duration", [50, 40, 45])

# Crear DataFrame a partir de las Series
df_entrenamiento = pl.DataFrame([serie_calorias, serie_duracion])

print(df_entrenamiento)

# %% [markdown]
# Cada Series se convierte en una columna del DataFrame, usando el nombre de la Series como cabecera de la columna.
#
# ---
#
# ## Resumen visual
#
# | Concepto                   | Descripción                                                    |
# | -------------------------- | -------------------------------------------------------------- |
# | **Series** | Columna unidimensional en Polars, con nombre y un solo tipo. |
# | **Creación** | `pl.Series("nombre", [datos])`                               |
# | **Índice** | No tiene índice explícito como Pandas; acceso por posición.      |
# | **Acceso a datos** | Por posición (`serie[0]`), slicing (`serie[1:4]`).            |
# | **Operaciones** | Vectorizadas (+, *, >, etc.), estadísticas (`.sum()`, `.mean()`). |
# | **Relación con DataFrame** | Un DataFrame está formado por varias Series.                   |
#
# ---
#
# ## **Actividad práctica: “Tu primera Series con Polars”**
#
# **Objetivo:** Crear, explorar y realizar operaciones básicas con una *Series* de Polars.
#
# ### Paso 1: Crear una *Series* de métricas de modelos de IA
#
# Crea una *Series* llamada `"precision"` con los siguientes valores de precisión de 5 modelos diferentes: `[0.85, 0.92, 0.78, 0.92, 0.88]`.

# %%
# Tu código aquí
import polars as pl

precisiones = [0.85, 0.92, 0.78, 0.92, 0.88]
serie_precision = pl.Series("precision", precisiones)
print(serie_precision)

# %% [markdown]
# ### Paso 2: Acceder a valores específicos
#
# * Muestra el valor de precisión del segundo modelo (posición 1).
# * Muestra los valores de precisión de los modelos 2, 3 y 4 (posiciones 1 a 3).

# %%
# Tu código aquí
print(f"Precisión del segundo modelo: {serie_precision[1]}")
print("\nPrecisiones de los modelos 2 a 4:")
print(serie_precision[1:4])

# %% [markdown]
# ### Paso 3: Realizar operaciones y cálculos
#
# * Calcula la precisión media de todos los modelos.
# * Encuentra la precisión máxima.
# * Crea una nueva *Series* booleana que indique qué modelos tienen una precisión superior a 0.90.

# %%
# Tu código aquí
print(f"Precisión media: {serie_precision.mean():.3f}")
print(f"Precisión máxima: {serie_precision.max()}")

precision_alta = serie_precision > 0.90
print("\n¿Precisión > 0.90?:")
print(precision_alta)

# %% [markdown]
# ### Paso 4: Contar valores
#
# * ¿Cuántos modelos tienen exactamente una precisión de 0.92? (Usa `value_counts()`).

# %%
# Tu código aquí
print("\nRecuento de cada valor de precisión:")
print(serie_precision.value_counts())

# %% [markdown]
# **Reflexión final**
#
# * ¿Qué ventajas notas al realizar operaciones vectorizadas (ej. `serie + 5`) en lugar de usar un bucle `for`?
# * ¿Cómo crees que la falta de un índice explícito (como en Pandas) afecta la forma de trabajar con Series en Polars?
#
# ---
#
# **Próxima sección:** *Polars DataFrames – La estructura central para el análisis de datos rápido y eficiente.*

# %% [markdown]
# # Introducción a los DataFrames en Polars 🚀
#
# ## ¿Qué es un DataFrame en Polars?
#
# Un **DataFrame** de **Polars** es la estructura de datos principal para trabajar con **datos tabulares** (organizados en filas y columnas).
# Es similar a una tabla de base de datos, una hoja de cálculo de Excel, o un DataFrame de Pandas, pero está diseñado desde cero para ser **extremadamente rápido y eficiente con la memoria**.
#
# 🔹 Es **bidimensional** (filas y columnas).
# 🔹 Cada columna es una **Polars Series** con un nombre y un tipo de dato único.
# 🔹 **No tiene un índice** como Pandas; las filas se identifican por su posición.
# 🔹 Optimizado para **procesamiento en paralelo** y **manejo de grandes datasets**.
#
# ---
#
# ## Crear un DataFrame
#
# Puedes crear un DataFrame de Polars a partir de varias fuentes:
#
# 📘 **Ejemplo 1: Desde un diccionario de listas (como en Pandas)**

# %%
import polars as pl

data_dict = {
  "columna_a": [1, 2, 3, 4, 5],
  "columna_b": ["A", "B", "C", "D", "E"],
  "columna_c": [True, False, True, False, True]
}

df_dict = pl.DataFrame(data_dict)
print(df_dict)

# %% [markdown]
# 📘 **Ejemplo 2: Desde una lista de diccionarios (cada dict es una fila)**
#
# Esto es útil si tus datos vienen en formato JSON de registros.

# %%
data_list_dict = [
    {"id": 1, "producto": "Laptop", "precio": 1200},
    {"id": 2, "producto": "Teclado", "precio": 75},
    {"id": 3, "producto": "Mouse", "precio": 25}
]

df_list_dict = pl.DataFrame(data_list_dict)
print(df_list_dict)

# %% [markdown]
# 📘 **Ejemplo 3: Desde un array de NumPy**
#
# Necesitas proporcionar los nombres de las columnas.

# %%
import numpy as np

data_np = np.array([[1.0, 2.5], [3.0, 4.5], [5.0, 6.5]])
column_names = ["sensor_1", "sensor_2"]

df_np = pl.DataFrame(data_np, schema=column_names)
print(df_np)

# %% [markdown]
# ---
#
# ## Seleccionar Filas y Columnas
#
# Polars utiliza una sintaxis basada en **expresiones** para seleccionar y manipular datos, lo que es muy potente.
#
# ### Seleccionar Columnas (`.select()`)
#
# Usa el método `.select()` para elegir qué columnas mostrar.

# %%
# Seleccionar solo 'columna_a' y 'columna_c'
seleccion_cols = df_dict.select([
    pl.col("columna_a"),
    pl.col("columna_c")
])
print(seleccion_cols)

# %% [markdown]
# **Nota:** `pl.col("nombre")` crea una **expresión** que se refiere a esa columna. Polars trabaja mucho con expresiones.
#
# ---
#
# ### Seleccionar Filas (`.filter()`)
#
# Usa `.filter()` con una expresión de condición para seleccionar filas.

# %%
# Seleccionar filas donde 'columna_a' sea mayor que 3
filtro_filas = df_dict.filter(
    pl.col("columna_a") > 3
)
print(filtro_filas)

# Seleccionar filas donde 'columna_c' sea True
filtro_boolean = df_dict.filter(
    pl.col("columna_c") == True # O simplemente pl.col("columna_c")
)
print("\nFilas con columna_c == True:")
print(filtro_boolean)

# %% [markdown]
# ---
#
# ### Acceder por posición (slicing)
#
# Puedes usar slicing similar a Python/NumPy para seleccionar un rango de filas.

# %%
# Seleccionar las primeras 3 filas
print("Primeras 3 filas:")
print(df_dict[0:3])

# Seleccionar filas desde la posición 2 hasta el final
print("\nDesde la fila 2:")
print(df_dict[2:])

# %% [markdown]
# ---
#
# ## Cargar Datos desde Archivos (CSV, JSON, etc.)
#
# Polars brilla especialmente al leer archivos grandes. Usa funciones como `pl.read_csv()` o `pl.read_json()`.
#
# 📘 **Ejemplo: Cargar un CSV (Dataset de Pokémon)**
#
# Usaremos el mismo dataset de Pokémon que en el tutorial de Pandas.

# %%
import polars as pl

url_pokemon = "https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Pokemon.csv"

# Leer el CSV directamente desde la URL
df_pokemon = pl.read_csv(url_pokemon)

# Mostrar las primeras 5 filas (head es similar a Pandas)
print(df_pokemon.head())

# %% [markdown]
# **Ventaja de Polars:** `read_csv` intenta inferir los tipos de datos de forma muy eficiente (`infer_schema_length`). Puede manejar archivos más grandes que la RAM usando `scan_csv` (lo veremos después).
#
# > Si tu CSV usa un separador diferente (ej. punto y coma ';'), puedes especificarlo: `pl.read_csv(url, separator=';')`
#
# ---
#
# ## Explorar el DataFrame
#
# Polars ofrece métodos para entender la estructura y contenido del DataFrame:
#
# * `.shape`: Devuelve una tupla `(num_filas, num_columnas)`.
# * `.columns`: Devuelve una lista con los nombres de las columnas.
# * `.dtypes`: Devuelve una lista con los tipos de datos de cada columna.
# * `.schema`: Devuelve un diccionario con nombres y tipos de columnas.
# * `.head(n)`: Muestra las primeras `n` filas.
# * `.tail(n)`: Muestra las últimas `n` filas.
# * `.describe()`: Calcula estadísticas descriptivas básicas para columnas numéricas.

# %%
print(f"Dimensiones del DataFrame: {df_pokemon.shape}")
print(f"\nNombres de columnas: {df_pokemon.columns}")
print(f"\nTipos de datos: {df_pokemon.dtypes}")
# print("\nSchema detallado:")
# print(df_pokemon.schema)
print("\nEstadísticas descriptivas:")
print(df_pokemon.describe())

# %% [markdown]
# ---
#
# ## Resumen
#
# | Concepto                   | Descripción                                                     |
# | -------------------------- | --------------------------------------------------------------- |
# | **DataFrame** | Estructura tabular 2D, optimizada para rendimiento.           |
# | **Creación** | `pl.DataFrame()`, `pl.read_csv()`, `pl.read_json()`, etc.       |
# | **Selección Columnas** | `.select([pl.col("..."), ...])`                               |
# | **Selección Filas** | `.filter(expresión_condición)`, slicing (`df[start:end]`)      |
# | **Exploración** | `.shape`, `.columns`, `.dtypes`, `.head()`, `.tail()`, `.describe()` |
# | **Característica Clave** | Uso de **expresiones** (`pl.col()`) para seleccionar y filtrar. |
#
# ---

# %% [markdown]
# # **Actividad práctica: Análisis de Pokémon con Polars** ⚡
#
# 🎯 **Objetivo:** Aplicar los conceptos básicos de Polars DataFrames para cargar, explorar y analizar el dataset de Pokémon.
#
# 📂 **Dataset:**
# [`Pokemon.csv`](https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Pokemon.csv)
#
# ---
#
# ## 🔹 Paso 1. Cargar el dataset
#
# Usa `pl.read_csv()` para cargar los datos desde la URL en un DataFrame llamado `df_poke`.

# %%
# Tu código aquí
import polars as pl

url_pokemon = "https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Pokemon.csv"
df_poke = pl.read_csv(url_pokemon)

print("Dataset cargado:")
print(df_poke.head(3))

# %% [markdown]
# ---
#
# ## 🔹 Paso 2. Explorar la estructura
#
# * ¿Cuántas filas y columnas tiene (`shape`)?
# * ¿Cuáles son los nombres de las columnas (`columns`)?
# * ¿Qué tipos de datos tienen las columnas (`dtypes`)?

# %%
# Tu código aquí
print(f"Dimensiones: {df_poke.shape}")
print(f"\nColumnas: {df_poke.columns}")
print(f"\nTipos de datos: {df_poke.dtypes}")

# %% [markdown]
# ---
#
# ## 🔹 Paso 3. Seleccionar filas y columnas
#
# * Muestra solo las columnas `Name`, `Type 1`, `Attack` y `Defense` de los primeros 5 Pokémon (usa `select` y `head`).
# * Muestra los Pokémon de tipo `Fire` (usa `filter`).
# * Muestra los Pokémon legendarios (`Legendary == True`) que tengan un `Attack` > 150 (usa `filter` con condiciones combinadas `&`).

# %%
# Tu código aquí
# Seleccionar columnas y primeras filas
print("Columnas seleccionadas (primeros 5):")
print(df_poke.select(["Name", "Type 1", "Attack", "Defense"]).head(5))

# Filtrar por tipo 'Fire'
print("\nPokémon de tipo Fire:")
print(df_poke.filter(pl.col("Type 1") == "Fire").head(3)) # Mostramos solo los 3 primeros

# Filtrar Legendarios con Attack > 150
print("\nLegendarios con Attack > 150:")
print(df_poke.filter(
    (pl.col("Legendary") == True) & (pl.col("Attack") > 150)
))

# %% [markdown]
# ---
#
# ## 🔹 Paso 4. Crear una nueva columna
#
# Crea una columna llamada `Attack_Defense_Ratio` que sea el resultado de dividir `Attack` entre `Defense`. Usa `.with_columns()`.
# Muestra el `Name` y esta nueva columna para los 5 primeros Pokémon.

# %%
# Tu código aquí
df_poke_ratio = df_poke.with_columns(
    (pl.col("Attack") / pl.col("Defense")).alias("Attack_Defense_Ratio")
)

print("Ratio Ataque/Defensa (primeros 5):")
print(df_poke_ratio.select(["Name", "Attack_Defense_Ratio"]).head())

# %% [markdown]
# ---
#
# ## 🔹 Paso 5. Agrupación y agregación (Reto)
#
# Calcula el promedio (`mean`) de `Attack` para cada `Type 1` de Pokémon. Usa `.group_by()` y `.agg()`.
# Ordena los resultados por el ataque medio de mayor a menor (`sort`).

# %%
# Tu código aquí
ataque_medio_por_tipo = df_poke.group_by("Type 1").agg(
    pl.mean("Attack").alias("Ataque_Medio")
).sort("Ataque_Medio", descending=True)

print("Ataque medio por Tipo 1 (ordenado):")
print(ataque_medio_por_tipo)

# %% [markdown]
# **Reflexión:**
#
# * ¿Qué te parece la sintaxis de expresiones de Polars (`pl.col()`, `.filter()`, `.select()`, `.with_columns()`) comparada con la de Pandas?
# * Si este dataset fuera mucho más grande (millones de filas), ¿qué ventajas esperarías de usar Polars?
#
# ---
#
# Estos pasos (cargar, explorar, seleccionar, transformar, agregar) son fundamentales en cualquier proyecto de análisis de datos o preparación para *Machine Learning*.

# %% [markdown]
# # **Lección: Lazy Evaluation en Polars** ⏳➡️🚀
#
# ---
#
# ## 1. ¿Qué es la Ejecución *Lazy* (Perezosa)?
#
# Una de las características más importantes y potentes de Polars es su **motor de ejecución *lazy***.
# A diferencia de Pandas, que ejecuta cada operación inmediatamente (*eager execution*), Polars **no ejecuta las operaciones hasta que es estrictamente necesario**.
#
# **¿Cómo funciona?**
#
# 1.  **Plan de Consulta**: Cuando escribes una cadena de operaciones (`.select()`, `.filter()`, `.group_by()`, etc.) sobre un `LazyFrame`, Polars no calcula nada todavía. Simplemente **construye un plan lógico** de lo que quieres hacer.
# 2.  **Optimización**: Antes de ejecutar, Polars **analiza y optimiza** este plan. Puede reordenar operaciones, fusionarlas, o elegir algoritmos más eficientes según el plan completo.
# 3.  **Ejecución**: Solo cuando pides explícitamente el resultado (normalmente con el método `.collect()`), Polars ejecuta el plan optimizado, a menudo en paralelo, para obtener el DataFrame final.
#
# **Analogía:** Imagina que pides a un chef que prepare varios platos. En lugar de cocinar cada uno por separado (eager), el chef anota todo el pedido (plan), piensa la mejor forma de usar los hornos y fuegos a la vez (optimización), y solo entonces empieza a cocinar todo eficientemente (ejecución con `.collect()`).
#
# ---
#
# ## 2. Beneficios de la Ejecución *Lazy*
#
# * **Mayor Rendimiento**: La optimización del plan permite a Polars encontrar la forma más rápida de obtener el resultado, evitando cálculos intermedios innecesarios.
# * **Menor Uso de Memoria**: No se crean DataFrames intermedios para cada paso, reduciendo el consumo de RAM.
# * **Procesamiento Out-of-Core**: Permite trabajar con datasets más grandes que la memoria disponible, ya que Polars puede procesar los datos en *chunks* (trozos) si es necesario (especialmente con formatos como Parquet).
# * **Claridad del Código**: Fomenta escribir cadenas de operaciones lógicas que describen la transformación completa.
#
# ---
#
# ## 3. ¿Cómo usar el Modo *Lazy*?
#
# Para trabajar en modo *lazy*, necesitas empezar con un `LazyFrame` en lugar de un `DataFrame`.
#
# ### Creando un `LazyFrame`
#
# 🔹 **Desde un archivo (método recomendado)**: Usa `pl.scan_csv()`, `pl.scan_parquet()`, `pl.scan_json()`, etc. Estas funciones *escanean* el archivo para conocer su estructura, pero no cargan los datos inmediatamente.

# %%
import polars as pl

url_pokemon = "https://raw.githubusercontent.com/MainakRepositor/Datasets/refs/heads/master/Pokemon.csv"

# Escanear el CSV para crear un LazyFrame
lazy_df = pl.scan_csv(url_pokemon)

print(type(lazy_df)) # Verás que es un LazyFrame

# %% [markdown]
# 🔹 **Desde un DataFrame existente**: Usa el método `.lazy()`.

# %%
# Crear un DataFrame eager primero (menos común para empezar)
eager_df = pl.DataFrame({"a": [1, 2], "b": [3, 4]})

# Convertirlo a LazyFrame
lazy_from_eager = eager_df.lazy()

print(type(lazy_from_eager))

# %% [markdown]
# ### Aplicando Operaciones
#
# Puedes aplicar las mismas operaciones (`.select`, `.filter`, `.with_columns`, `.group_by`, etc.) a un `LazyFrame`. Polars solo añadirá pasos al plan de consulta.

# %%
# Construir un plan sobre el LazyFrame de Pokémon
plan_consulta = (
    lazy_df
    .filter(pl.col("Type 1") == "Water") # Filtrar Pokémon de agua
    .filter(pl.col("Attack") > 100)      # Con ataque mayor a 100
    .select(["Name", "Attack", "Defense"]) # Seleccionar columnas
    .sort("Attack", descending=True)      # Ordenar por ataque
)

print("Tipo del plan:", type(plan_consulta)) # Sigue siendo un LazyFrame
print("\nPlan de consulta (simplificado):")
print(plan_consulta.explain(optimized=True)) # Muestra el plan optimizado

# %% [markdown]
# **Nota:** `.explain()` es útil para ver cómo Polars optimiza tu consulta.
#
# ### Ejecutando la Consulta (`.collect()`)
#
# Para obtener el resultado final como un `DataFrame` (eager), usa `.collect()`.

# %%
# Ejecutar el plan y obtener el DataFrame resultante
resultado_df = plan_consulta.collect()

print("\nTipo del resultado:", type(resultado_df))
print("\nResultado final (Pokémon de Agua con Ataque > 100):")
print(resultado_df)

# %% [markdown]
# **Solo en este último paso (`.collect()`) Polars realmente lee el archivo CSV, aplica los filtros y selecciones optimizados, y devuelve el resultado.**
#
# ---
#
# ## 4. ¿Cuándo usar *Lazy* vs *Eager*?
#
# * **Usa *Lazy* (`scan_...`, `.lazy()`, `.collect()`):**
#     * Para **datasets grandes** o que no caben en memoria.
#     * Cuando realizas **múltiples operaciones encadenadas** (filtros, selecciones, agregaciones).
#     * Para obtener el **máximo rendimiento**.
#     * **Casi siempre es la forma recomendada** de empezar en Polars, especialmente leyendo archivos.
#
# * **Usa *Eager* (`pl.DataFrame()`, `pl.read_...`):**
#     * Para **datasets pequeños** donde la optimización no es crítica.
#     * Cuando necesitas **resultados intermedios inmediatos** (menos común en Polars).
#     * Al crear DataFrames pequeños **directamente en memoria** (ej. desde diccionarios).
#
# ---
#
# ## ✅ **Resumen**
#
# | Concepto            | Descripción                                                                          |
# | ------------------- | ------------------------------------------------------------------------------------ |
# | **Lazy Evaluation** | Polars planifica y optimiza las operaciones antes de ejecutarlas.                    |
# | **LazyFrame** | Objeto que representa un plan de consulta, no los datos en sí.                       |
# | **Crear LazyFrame** | `pl.scan_csv()`, `pl.scan_parquet()`, `df.lazy()`                                     |
# | **Construir Plan** | Aplicar `.select()`, `.filter()`, etc., a un `LazyFrame`.                            |
# | **Ejecutar Plan** | `.collect()`: Ejecuta el plan optimizado y devuelve un `DataFrame` (eager).          |
# | **Ver Plan** | `.explain()`: Muestra el plan de ejecución lógico u optimizado.                      |
# | **Beneficios** | Mejor rendimiento, menor uso de memoria, capacidad para datos grandes (out-of-core). |
#
# ---

# %% [markdown]
# # **Lección: La API de Expresiones de Polars** ✨
#
# ---
#
# ## 1. ¿Qué son las Expresiones en Polars?
#
# Las **expresiones** son el corazón ❤️ de la API de Polars. Son la forma en que **describes las operaciones** que quieres realizar sobre tus columnas, sin decirle a Polars *cómo* hacerlas exactamente.
#
# Piensa en una expresión como una **receta** o una **fórmula** que Polars puede entender, optimizar y aplicar a los datos.
#
# **Características Clave:**
#
# * **Declarativas**: Describen *qué* quieres hacer, no *cómo*.
# * **Componibles**: Puedes combinar expresiones simples para crear transformaciones complejas.
# * **Optimizables**: El motor *lazy* de Polars las optimiza antes de la ejecución.
# * **Paralelizables**: Polars puede ejecutar expresiones en paralelo sobre diferentes partes de los datos.
#
# La función principal para crear expresiones es `pl.col("nombre_columna")`, que selecciona una columna.
#
# ---
#
# ## 2. Contextos de Uso de Expresiones
#
# Las expresiones se utilizan dentro de varios métodos clave de los DataFrames (o LazyFrames):
#
# * **`.select()`**: Para seleccionar columnas existentes o crear nuevas.
# * **`.filter()`**: Para seleccionar filas basadas en condiciones.
# * **`.with_columns()`**: Para añadir o modificar columnas.
# * **`.group_by().agg()`**: Para realizar agregaciones (sumas, medias, etc.) sobre grupos.
# * **`.sort()`**: Para ordenar el DataFrame.
#
# ---
#
# ## 3. Ejemplos de Expresiones Comunes
#
# Vamos a usar un DataFrame de ejemplo:

# %%
import polars as pl

df = pl.DataFrame({
    "id": [1, 2, 3, 4, 5],
    "categoria": ["A", "B", "A", "B", "C"],
    "valor": [10, 25, 10, 30, 15],
    "coste": [5, 10, 8, 12, 7]
})
print(df)

# %% [markdown]
# ### 🔹 Selección Simple (`pl.col()`)

# %%
# Seleccionar las columnas 'id' y 'valor'
df_seleccion = df.select([
    pl.col("id"),
    pl.col("valor")
])
print(df_seleccion)

# %% [markdown]
# ### 🔹 Alias (`.alias()`)
#
# Para renombrar una columna en la salida.

# %%
# Seleccionar 'valor' y renombrarla a 'precio'
df_alias = df.select([
    pl.col("valor").alias("precio")
])
print(df_alias)

# %% [markdown]
# ### 🔹 Operaciones Aritméticas
#
# Puedes realizar cálculos directamente en las expresiones.

# %%
# Calcular el beneficio (valor - coste)
df_beneficio = df.with_columns([
    (pl.col("valor") - pl.col("coste")).alias("beneficio")
])
print(df_beneficio)

# %% [markdown]
# ### 🔹 Comparaciones y Lógica Booleana (`==`, `>`, `&`, `|`)
#
# Se usan principalmente en `.filter()`.

# %%
# Filtrar filas donde categoria es 'A' Y valor es 10
df_filtrado = df.filter(
    (pl.col("categoria") == "A") & (pl.col("valor") == 10)
)
print(df_filtrado)

# %% [markdown]
# ### 🔹 Funciones de Agregación (`.sum()`, `.mean()`, `.count()`, etc.)
#
# Se usan típicamente dentro de `.agg()` después de un `.group_by()`.

# %%
# Calcular la suma y la media de 'valor' por 'categoria'
df_agregado = df.group_by("categoria").agg([
    pl.sum("valor").alias("suma_valor"),
    pl.mean("valor").alias("media_valor")
])
print(df_agregado)

# %% [markdown]
# ### 🔹 Funciones sobre Cadenas (`.str`)
#
# Polars tiene un potente namespace `.str` para manipular texto.

# %%
# Convertir 'categoria' a minúsculas
df_minusculas = df.with_columns([
    pl.col("categoria").str.to_lowercase().alias("categoria_minuscula")
])
print(df_minusculas)

# %% [markdown]
# ### 🔹 Expresiones Condicionales (`pl.when().then().otherwise()`)
#
# Similar a un `IF-ELSE` en SQL o Excel.

# %%
# Crear columna 'tipo_valor' basado en 'valor'
df_condicional = df.with_columns([
    pl.when(pl.col("valor") > 20)
      .then(pl.lit("Alto")) # pl.lit() crea un valor literal
      .when(pl.col("valor") > 10)
      .then(pl.lit("Medio"))
      .otherwise(pl.lit("Bajo"))
      .alias("tipo_valor")
])
print(df_condicional)

# %% [markdown]
# ---
#
# ## 4. El Poder del Encadenamiento
#
# La verdadera potencia viene de **encadenar** estas expresiones y métodos para construir transformaciones complejas de forma legible.

# %%
# Ejemplo encadenado: Filtrar, crear columna, agrupar y ordenar
resultado_complejo = (
    df
    .filter(pl.col("coste") < 10) # 1. Filtrar por coste
    .with_columns([ # 2. Calcular beneficio
        (pl.col("valor") - pl.col("coste")).alias("beneficio")
    ])
    .group_by("categoria") # 3. Agrupar por categoria
    .agg([ # 4. Calcular beneficio medio y contar
        pl.mean("beneficio").alias("beneficio_medio"),
        pl.count().alias("num_items") # pl.count() cuenta filas por grupo
    ])
    .sort("beneficio_medio", descending=True) # 5. Ordenar
)

print(resultado_complejo)

# %% [markdown]
# Este estilo es muy común en Polars y es clave para aprovechar el motor *lazy* (si empezaras con `pl.scan_csv`, todo esto sería parte del plan optimizado).
#
# ---
#
# ## ✅ **Resumen**
#
# | Característica              | Descripción                                                               |
# | --------------------------- | ------------------------------------------------------------------------- |
# | **Expresión** | Fórmula/receta que describe una operación sobre columnas.                 |
# | **Creación** | `pl.col("nombre")`, operaciones (+, -, *, /), funciones (`.sum()`, etc.) |
# | **Contextos Principales** | `.select()`, `.filter()`, `.with_columns()`, `.agg()`                     |
# | **Alias** | `.alias("nuevo_nombre")` para renombrar el resultado de una expresión.    |
# | **Condicionales** | `pl.when().then().otherwise()` para lógica if-else.                       |
# | **Literal** | `pl.lit(valor)` para usar un valor constante en una expresión.            |
# | **Encadenamiento (Chaining)** | Conectar múltiples métodos para construir transformaciones complejas.     |
# | **Beneficio** | Código legible, optimizable y paralelizable por el motor de Polars.       |
#
# ---

# %% [markdown]
# # **Lección: Limpieza de Datos con Polars** 🧹
#
# ---
#
# ## 1. Importancia de la Limpieza de Datos
#
# Al igual que con Pandas, la **limpieza de datos** es un paso crucial antes de cualquier análisis o modelado en Polars. Los datos del mundo real rara vez son perfectos y suelen contener:
#
# * **Valores Nulos (`null`)**: Datos faltantes.
# * **Formatos Incorrectos**: Ej. números como texto, fechas inconsistentes.
# * **Datos Erróneos**: Valores imposibles o fuera de rango (ej. edad negativa).
# * **Duplicados**: Filas idénticas repetidas.
#
# Polars ofrece herramientas eficientes para abordar estos problemas, aprovechando su API de expresiones y su motor *lazy*.
#
# ---
#
# ## 2. Manejo de Valores Nulos (`null`)
#
# Polars usa `null` para representar datos faltantes.
#
# 📘 **Dataset de ejemplo con nulos:**

# %%
import polars as pl
import numpy as np # Lo usaremos para introducir NaNs fácilmente

df_nulos = pl.DataFrame({
    "col1": [1, 2, None, 4, 5],
    "col2": ["a", None, "c", "d", "e"],
    "col3": [10.0, 20.0, 30.0, None, 50.0]
})
print(df_nulos)

# %% [markdown]
# ### 🔹 Contar Nulos
# Usa `.null_count()`.

# %%
print(df_nulos.null_count())

# %% [markdown]
# ### 🔹 Eliminar Filas con Nulos (`.drop_nulls()`)
# Elimina todas las filas que contengan al menos un valor nulo.

# %%
df_sin_nulos = df_nulos.drop_nulls()
print(df_sin_nulos)

# %% [markdown]
# Puedes especificar columnas concretas con el argumento `subset`: `df_nulos.drop_nulls(subset=["col1", "col3"])`
#
# ### 🔹 Rellenar Nulos (`.fill_null()`)
# Reemplaza los valores nulos con un valor específico o una estrategia (como la media, mediana, etc.).

# %%
# Rellenar con un valor fijo (ej. 0 para col1, 'desconocido' para col2)
df_relleno_fijo = df_nulos.with_columns([
    pl.col("col1").fill_null(0),
    pl.col("col2").fill_null("desconocido")
])
print("Relleno con valor fijo:")
print(df_relleno_fijo)

# Rellenar col3 con la media de esa columna
df_relleno_media = df_nulos.with_columns([
    pl.col("col3").fill_null(pl.mean("col3")) # Expresión dentro de fill_null!
])
print("\nRelleno con la media:")
print(df_relleno_media)

# %% [markdown]
# **Nota:** `.fill_null()` puede aceptar un valor literal o *otra expresión* de Polars (como `pl.mean()`, `pl.median()`, `pl.lit()`), lo que lo hace muy flexible.
#
# ---
#
# ## 3. Corregir Formatos Incorrectos (`.cast()`)
#
# Si una columna tiene el tipo de dato incorrecto (ej. un número almacenado como texto), usa el método `.cast()` para convertirla.
#
# 📘 **Ejemplo:**

# %%
df_formatos = pl.DataFrame({
    "id": ["1", "2", "3"], # Números como texto
    "fecha_texto": ["2023-01-01", "2023-01-02", "2023-01-03"]
})
print("DataFrame Original:")
print(df_formatos)
print(df_formatos.dtypes)

# Convertir 'id' a entero y 'fecha_texto' a fecha
df_corregido = df_formatos.with_columns([
    pl.col("id").cast(pl.Int64), # Convertir a entero de 64 bits
    pl.col("fecha_texto").str.strptime(pl.Date, "%Y-%m-%d").alias("fecha") # Convertir texto a fecha
]).drop("fecha_texto") # Eliminar la columna de texto original

print("\nDataFrame Corregido:")
print(df_corregido)
print(df_corregido.dtypes)

# %% [markdown]
# **Explicación:**
# * `.cast(pl.Int64)` convierte la columna "id" a tipo entero.
# * `.str.strptime(pl.Date, "%Y-%m-%d")` parsea la cadena de texto "fecha_texto" usando el formato `Año-Mes-Día` y la convierte a tipo Fecha (`pl.Date`).
# * Usamos `.alias("fecha")` para darle un nuevo nombre y `.drop()` para quitar la original.
#
# Polars ofrece muchos tipos de datos (`pl.Int32`, `pl.Float64`, `pl.Utf8` (texto), `pl.Boolean`, `pl.Datetime`, etc.).
#
# ---
#
# ## 4. Manejar Datos Erróneos
#
# Para corregir valores que son lógicamente incorrectos (pero tienen el tipo correcto), puedes usar:
#
# * **`.filter()`**: Para eliminar filas con valores erróneos.
# * **`pl.when().then().otherwise()`**: Para reemplazar valores basados en condiciones.
#
# 📘 **Ejemplo: Corregir una duración imposible**

# %%
df_erroneo = pl.DataFrame({"duracion_min": [60, 45, 9999, 75, -10]})
print("Datos originales:")
print(df_erroneo)

# Opción 1: Eliminar filas con duración > 180 o < 0
df_filtrado_err = df_erroneo.filter(
    (pl.col("duracion_min") <= 180) & (pl.col("duracion_min") >= 0)
)
print("\nFiltrando valores erróneos:")
print(df_filtrado_err)

# Opción 2: Reemplazar valores erróneos (ej. con la mediana)
mediana_duracion = df_erroneo.filter(
    (pl.col("duracion_min") <= 180) & (pl.col("duracion_min") >= 0)
)["duracion_min"].median()

df_reemplazado_err = df_erroneo.with_columns([
    pl.when((pl.col("duracion_min") > 180) | (pl.col("duracion_min") < 0))
      .then(mediana_duracion)
      .otherwise(pl.col("duracion_min"))
      .alias("duracion_corregida")
])
print("\nReemplazando valores erróneos con mediana:")
print(df_reemplazado_err)

# %% [markdown]
# ---
#
# ## 5. Eliminar Duplicados (`.unique()`)
#
# Para eliminar filas completamente duplicadas, usa `.unique()`.

# %%
df_duplicados = pl.DataFrame({
    "a": [1, 2, 1, 3, 2],
    "b": ["x", "y", "x", "z", "y"]
})
print("Con duplicados:")
print(df_duplicados)

df_sin_duplicados = df_duplicados.unique()
print("\nSin duplicados:")
print(df_sin_duplicados)

# %% [markdown]
# Puedes usar `subset` para considerar duplicados basados solo en ciertas columnas y `keep` para decidir cuál fila mantener (`'first'`, `'last'`, `'none'`):
# `df_duplicados.unique(subset=["a"], keep='first')`
#
# ---
#
# ## ✅ **Resumen de Limpieza**
#
# | Tarea                  | Método Polars                             | Descripción                                    |
# | ---------------------- | ----------------------------------------- | ---------------------------------------------- |
# | Contar Nulos           | `.null_count()`                           | Cuenta nulos por columna.                      |
# | Eliminar Filas Nulas   | `.drop_nulls(subset=...)`                 | Elimina filas con nulos (opcionalmente en subset). |
# | Rellenar Nulos         | `.fill_null(valor_o_expresión)`           | Reemplaza nulos.                               |
# | Convertir Tipo         | `.cast(pl.DataType)`                      | Cambia el tipo de dato de la columna.          |
# | Convertir Texto a Fecha| `.str.strptime(pl.Date, "formato")`   | Parsea fechas desde texto.                     |
# | Filtrar Errores        | `.filter(condición)`                      | Elimina filas que no cumplen la condición.     |
# | Reemplazar Errores     | `.with_columns(pl.when()...)`             | Reemplaza valores basados en condiciones.      |
# | Eliminar Duplicados    | `.unique(subset=..., keep=...)`           | Elimina filas duplicadas.                      |
#
# ---

# %% [markdown]
# # **Lección: Correlaciones de Datos en Polars** 📈📉
#
# ---
#
# ## 1. Correlación: Midiendo la Relación entre Variables
#
# La **correlación** es una medida estadística que describe la **fuerza y dirección de la relación lineal** entre dos variables numéricas.
# Es fundamental en el análisis exploratorio de datos (EDA) y en la selección de características (*feature selection*) para modelos de Machine Learning.
#
# El **coeficiente de correlación** (usualmente Pearson) varía entre **-1 y +1**:
#
# * **+1**: Correlación positiva perfecta (si una variable sube, la otra sube proporcionalmente).
# * **-1**: Correlación negativa perfecta (si una variable sube, la otra baja proporcionalmente).
# * **0**: No hay correlación lineal (las variables no se mueven juntas de forma lineal).
# * Valores cercanos a +1 o -1 indican una relación fuerte; valores cercanos a 0 indican una relación débil.
#
# ---
#
# ## 2. Calcular Correlaciones en Polars
#
# Polars permite calcular la matriz de correlación entre las columnas numéricas de un DataFrame usando el método `.corr()`.
#
# 📘 **Dataset de ejemplo (datos de entrenamiento):**

# %%
import polars as pl

url = 'https://raw.githubusercontent.com/carlostessier/DataSets/refs/heads/main/csv/training_data.csv'
# Usamos read_csv porque el dataset es pequeño; para grandes, scan_csv sería mejor
df_train = pl.read_csv(url)

# Eliminar filas con valores nulos para el cálculo de correlación
df_train = df_train.drop_nulls()

print("Datos de entrenamiento (sin nulos):")
print(df_train.head())

# %% [markdown]
# ### 🔹 Calcular la Matriz de Correlación

# %%
# Calcular la correlación entre todas las columnas numéricas
corr_matrix = df_train.corr()

print("\nMatriz de Correlación:")
print(corr_matrix)

# %% [markdown]
# ---
#
# ## 3. Interpretación de la Matriz
#
# La tabla resultante muestra el coeficiente de correlación entre cada par de columnas:
#
# * La diagonal siempre es **1.0**, ya que una variable está perfectamente correlacionada consigo misma.
# * La matriz es **simétrica**: la correlación entre A y B es la misma que entre B y A.
#
# **Observaciones del ejemplo:**
#
# * `Duration` y `Calories` tienen una **correlación positiva muy alta** (0.92): a mayor duración, más calorías quemadas (esperado).
# * `Pulse` y `Maxpulse` tienen una **correlación positiva fuerte** (0.79): pulsaciones medias y máximas tienden a subir juntas.
# * `Duration` y `Maxpulse` tienen una **correlación muy baja** (cercana a 0): no hay relación lineal clara entre cuánto dura el ejercicio y cuál es el pulso máximo alcanzado en ese ejercicio específico.
# * `Pulse` y `Calories` tienen una **correlación muy baja** (0.02): el pulso medio por sí solo no predice bien las calorías quemadas (la duración es mucho más importante aquí).
#
# ---
#
# ## 4. Visualización con un Mapa de Calor (Heatmap)
#
# Una matriz de correlación es más fácil de interpretar visualmente usando un mapa de calor. Podemos usar `seaborn` y `matplotlib` (necesitarás tenerlos instalados: `pip install seaborn matplotlib`).
#
# **Importante:** Seaborn trabaja directamente con DataFrames de Pandas. Necesitamos convertir la matriz de correlación de Polars a Pandas usando `.to_pandas()`.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convertir la matriz de correlación de Polars a Pandas para Seaborn
corr_matrix_pd = corr_matrix.to_pandas()

# La primera columna ('column') contiene los nombres, la usamos como índice
corr_matrix_pd = corr_matrix_pd.set_index('column')

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix_pd, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Matriz de Correlación de Datos de Entrenamiento')
plt.show()

# %% [markdown]
# **Interpretación del Heatmap:**
# * Colores **rojos cálidos**: Correlación positiva fuerte.
# * Colores **azules fríos**: Correlación negativa fuerte.
# * Colores **cercanos al blanco**: Correlación débil o nula.
#
# Vemos claramente las relaciones fuertes entre (Duration, Calories) y (Pulse, Maxpulse).
#
# ---
#
# ## 5. Correlación en Ciencia de Datos e IA
#
# * **Selección de Características**: Si dos variables de entrada (`features`) están muy correlacionadas (ej. > 0.9 o < -0.9), pueden ser redundantes. Mantener solo una puede simplificar el modelo sin perder mucha información.
# * **Entendimiento del Problema**: Ayuda a comprender qué variables están relacionadas con la variable objetivo que queremos predecir.
# * **Detección de Multicolinealidad**: En modelos como la regresión lineal, una alta correlación entre variables predictoras puede causar problemas de estabilidad.
#
# ⚠️ **Importante:** Correlación **no implica causalidad**. Que dos variables se muevan juntas no significa que una cause la otra.
#
# ---
#
# ## ✅ **Resumen**
#
# | Tarea                      | Método / Función                 | Descripción                                                   |
# | -------------------------- | -------------------------------- | ------------------------------------------------------------- |
# | Calcular Matriz Correlación| `df.corr()`                      | Calcula correlación (Pearson por defecto) entre columnas num. |
# | Interpretación             | Valor entre -1 y +1              | Mide fuerza y dirección de la relación lineal.                |
# | Visualización              | `seaborn.heatmap()` (con Pandas) | Mapa de calor para fácil interpretación visual.               |
# | Convertir Polars a Pandas  | `.to_pandas()`                   | Necesario para usar con algunas bibliotecas como Seaborn.     |
# | Aplicación                 | EDA, Selección de Features       | Entender relaciones, detectar redundancia.                    |
#
# ---
